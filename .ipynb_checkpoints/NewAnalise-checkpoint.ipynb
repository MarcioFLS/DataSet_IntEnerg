# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
from datetime import datetime as dt
import time as tm

# %%
int_enel = pd.read_csv('interrupcoes_enel.csv')
int_enel
# Out:
#      DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 0                 26/05/2023                      TRINDADE
# 1                 26/05/2023                      BOM NOME
# 2                 26/05/2023                     ARARIPINA
# 3                 26/05/2023                   PAU AMARELO
# 4                 26/05/2023                     ARARIPINA
# ...                      ...                           ...
# 4995              26/05/2023                      PRAZERES
# 4996              26/05/2023                     MACAXEIRA
# 4997              26/05/2023                      TIMBAUBA
# 4998              26/05/2023                    PONTEZINHA
# 4999                     NaN                           NaN
#
#      DscAlimentadorSubestacao DscSubestacaoDistribuicao NumOrdemInterrupcao  \
# 0                    TDD-01C5                  TRINDADE   15326228_14086699
# 1                    SJB-01J3      SAO JOSE DO BELMONTE   15326358_14086719
# ...

# %%
# Checar se tem algum valor nulo
int_enel.isnull()
# Out:
#       DatGeracaoConjuntoDados  DscConjuntoUnidadeConsumidora  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
# ...                       ...                            ...
# 4995                    False                          False
# 4996                    False                          False
# 4997                    False                          False
# 4998                    False                          False
# 4999                     True                           True
#
#       DscAlimentadorSubestacao  DscSubestacaoDistribuicao  \
# 0                        False                      False
# 1                        False                      False
# ...

# %%
int_enel.isnull().T
# Out:
#                                 0      1      2      3      4      5     \
# DatGeracaoConjuntoDados        False  False  False  False  False  False
# DscConjuntoUnidadeConsumidora  False  False  False  False  False  False
# DscAlimentadorSubestacao       False  False  False  False  False  False
# DscSubestacaoDistribuicao      False  False  False  False  False  False
# NumOrdemInterrupcao            False  False  False  False  False  False
# DscTipoInterrupcao             False  False  False  False  False  False
# IdeMotivoInterrupcao           False  False  False  False  False  False
# DataInicioInterrupcao          False  False  False  False  False  False
# HoraIcicioInterrupcao          False  False  False  False  False  False
# DatFimInterrupcao              False  False  False  False  False  False
# DscFatoGeradorInterrupcao      False  False  False  False  False  False
# NumNivelTensao                 False  False  False  False  False  False
# ...

# %%
# Retornar apenas linhas que tem valores nulos
int_enel.isnull().T.any()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999     True
# Length: 5000, dtype: bool

# %%
int_enel[int_enel.isnull().T.any()]
# Out:
#      DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 4999                     NaN                           NaN
#
#      DscAlimentadorSubestacao DscSubestacaoDistribuicao NumOrdemInterrupcao  \
# 4999                      NaN                       NaN                 NaN
#
#      DscTipoInterrupcao  IdeMotivoInterrupcao DataInicioInterrupcao  \
# 4999                NaN                   NaN                   NaN
#
#      HoraIcicioInterrupcao DatFimInterrupcao DscFatoGeradorInterrupcao  \
# 4999                   NaN               NaN                       NaN
#
#       NumNivelTensao  NumUnidadeConsumidora  NumConsumidorConjunto  NumAno  \
# 4999             NaN                    NaN                    NaN     NaN
#
#      NomAgenteRegulado SigAgente NumCPFCNPJ  VlrIndiceEnviado
# 4999               NaN       NaN        NaN                 0

# %%
int_enel[int_enel.isnull().T.any()].index
# Out:
# Index([4999], dtype='int64')

# %%
int_enel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DatGeracaoConjuntoDados        4999 non-null   object
#  1   DscConjuntoUnidadeConsumidora  4999 non-null   object
#  2   DscAlimentadorSubestacao       4999 non-null   object
#  3   DscSubestacaoDistribuicao      4999 non-null   object
#  4   NumOrdemInterrupcao            4999 non-null   object
#  5   DscTipoInterrupcao             4999 non-null   object
#  6   IdeMotivoInterrupcao           4999 non-null   float64
#  7   DataInicioInterrupcao          4999 non-null   object
#  8   HoraIcicioInterrupcao          4999 non-null   object
#  9   DatFimInterrupcao              4999 non-null   object
#  10  DscFatoGeradorInterrupcao      4999 non-null   object
#  11  NumNivelTensao                 4999 non-null   float64
# ...

# %% [markdown]
# ## Unidades

# %%
# Qunatidade de Unidade consumidora por interrupção em seu conjunto.
q_nunic = int_enel[['DscConjuntoUnidadeConsumidora', 'NumUnidadeConsumidora']]
print(q_nunic)
# Out:
#      DscConjuntoUnidadeConsumidora  NumUnidadeConsumidora
# 0                         TRINDADE                    1.0
# 1                         BOM NOME                    1.0
# 2                        ARARIPINA                    1.0
# 3                      PAU AMARELO                    1.0
# 4                        ARARIPINA                    1.0
# ...                            ...                    ...
# 4995                      PRAZERES                    1.0
# 4996                     MACAXEIRA                   89.0
# 4997                      TIMBAUBA                  186.0
# 4998                    PONTEZINHA                   13.0
# 4999                           NaN                    NaN
#
# [5000 rows x 2 columns]

# %%
# Total de unidade consumidora (soma)
int_enel['NumUnidadeConsumidora'].sum()
# Out:
# 1125665.0

# %%
# Valores estatíticos
int_enel['NumUnidadeConsumidora'].describe()
# Out:
# count     4999.000000
# mean       225.178036
# std        933.451995
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         56.000000
# max      14319.000000
# Name: NumUnidadeConsumidora, dtype: float64

# %%
# Mediana
int_enel['NumUnidadeConsumidora'].median()
# Out:
# 4.0

# %%
# Utilização do gráfico para detectar outliers
x = int_enel.loc[:,['NumUnidadeConsumidora']].index
y = int_enel.loc[:,['NumUnidadeConsumidora']].values
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Consumidores

# %%
# Qunatidade de consumidor por interrupção em seu conjunto.
c_nunic = int_enel[['DscConjuntoUnidadeConsumidora', 'NumConsumidorConjunto']]
print(c_nunic)
# Out:
#      DscConjuntoUnidadeConsumidora  NumConsumidorConjunto
# 0                         TRINDADE                36413.0
# 1                         BOM NOME                26618.0
# 2                        ARARIPINA                29983.0
# 3                      PAU AMARELO                65319.0
# 4                        ARARIPINA                29983.0
# ...                            ...                    ...
# 4995                      PRAZERES                49874.0
# 4996                     MACAXEIRA                53970.0
# 4997                      TIMBAUBA                31402.0
# 4998                    PONTEZINHA                44675.0
# 4999                           NaN                    NaN
#
# [5000 rows x 2 columns]

# %%
# Total de consumidores (soma)
int_enel['NumConsumidorConjunto'].sum()
# Out:
# 164348776.0

# %%
int_enel['NumConsumidorConjunto'].describe()
# Out:
# count     4999.000000
# mean     32876.330466
# std      18398.610311
# min       1013.000000
# 25%      19745.000000
# 50%      29983.000000
# 75%      42647.000000
# max      88878.000000
# Name: NumConsumidorConjunto, dtype: float64

# %%
int_enel['NumUnidadeConsumidora'].median()
# Out:
# 4.0

# %%
import matplotlib.pyplot as plt
x = int_enel.loc[:,['NumConsumidorConjunto']].index
y = int_enel.loc[:,['NumConsumidorConjunto']].values
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Índice

# %%
q_ind = int_enel['VlrIndiceEnviado']
q_ind
# Out:
# 0        2820
# 1           0
# 2        1296
# 3          60
# 4        1756
#         ...
# 4995        0
# 4996        0
# 4997    27390
# 4998        0
# 4999        0
# Name: VlrIndiceEnviado, Length: 5000, dtype: int64

# %%
q_ind.describe()
# Out:
# count     5000.000000
# mean      1046.776600
# std       3690.749424
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        412.000000
# max      73931.000000
# Name: VlrIndiceEnviado, dtype: float64

# %%
int_enel['VlrIndiceEnviado'].median()
# Out:
# 0.0

# %%
q_ind.sum()
# Out:
# 5233883

# %%
x = int_enel.loc[:,['VlrIndiceEnviado']].index
y = int_enel.loc[:,['VlrIndiceEnviado']].values
plt.scatter(x,y)
plt.show()

# %%
# Gráficos para identificar as tensões afetadas.
x = int_enel.loc[:,['NumNivelTensao']].index
y = int_enel.loc[:,['NumNivelTensao']].values
plt.scatter(x,y)
plt.show()

# %%
# Qunatidade de Unidade consumidora por interrupção em seu conjunto.
q_nunic = int_enel[['DscConjuntoUnidadeConsumidora', 'NumUnidadeConsumidora']]
print(q_nunic)
# Out:
#      DscConjuntoUnidadeConsumidora  NumUnidadeConsumidora
# 0                         TRINDADE                    1.0
# 1                         BOM NOME                    1.0
# 2                        ARARIPINA                    1.0
# 3                      PAU AMARELO                    1.0
# 4                        ARARIPINA                    1.0
# ...                            ...                    ...
# 4995                      PRAZERES                    1.0
# 4996                     MACAXEIRA                   89.0
# 4997                      TIMBAUBA                  186.0
# 4998                    PONTEZINHA                   13.0
# 4999                           NaN                    NaN
#
# [5000 rows x 2 columns]

# %%
int_enel[int_enel.NumUnidadeConsumidora >=2000].groupby('DscConjuntoUnidadeConsumidora').max()
# Out:
#                               DatGeracaoConjuntoDados  \
# DscConjuntoUnidadeConsumidora
# AFOGADOS DA INGAZEIRA                      26/05/2023
# ARARIPINA                                  26/05/2023
# BARRA DE BEBEDOURO                         26/05/2023
# BOM JARDIM                                 26/05/2023
# BOM NOME                                   26/05/2023
# BONJI                                      26/05/2023
# BRIGIDA                                    26/05/2023
# CABO                                       26/05/2023
# CABROBO                                    26/05/2023
# CARPINA                                    26/05/2023
# CARUARU                                    26/05/2023
# CONDADO                                    26/05/2023
# CUSTODIA                                   26/05/2023
# ENSEADA DOS CORAIS                         26/05/2023
# FLORES                                     26/05/2023
# FLORESTA                                   26/05/2023
# ...

# %%
int_enel.groupby('DscAlimentadorSubestacao').count()

# %%
int_enel[['DscSubestacaoDistribuicao', 'NumUnidadeConsumidora']].groupby('DscSubestacaoDistribuicao').mean()
# Out:
#                              NumUnidadeConsumidora
# DscSubestacaoDistribuicao
# AFOGADOS DA INGAZEIRA                   945.902439
# AFRANIO                                  19.588235
# AGRESTINA                                26.951220
# AGUAS BELAS                              27.270833
# ANGELIM                                  29.350000
# ...                                            ...
# VENTUROSA                                15.600000
# VERTENTES                                15.567568
# VICENCIA                                364.757143
# VITORIA DE SANTO ANTAO                   49.582090
# VITORIA DE SANTO ANTAO DOIS             151.173913
#
# [146 rows x 1 columns]

# %%
x = int_enel.loc[:,['NumUnidadeConsumidora']].index
y = int_enel.loc[:,['DscSubestacaoDistribuicao']].values
plt.scatter(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 3
#       1 x = int_enel.loc[:,['NumUnidadeConsumidora']].index
#       2 y = int_enel.loc[:,['DscSubestacaoDistribuicao']].values
# ----> 3 plt.scatter(x,y)
#       4 plt.show()
#
# File C:\analise\ambiente\Lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
vdate = int_enel.groupby(int_enel['DataInicioInterrupcao'].dt.HoraIcicioInterrupcao)['VlrIndiceEnviado']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 vdate = int_enel.groupby(int_enel['DataInicioInterrupcao'].dt.HoraIcicioInterrupcao)['VlrIndiceEnviado']
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\generic.py:6202, in NDFrame.__getattr__(self, name)
#    6195 if (
#    6196     name not in self._internal_names_set
#    6197     and name not in self._metadata
#    6198     and name not in self._accessors
#    6199     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200 ):
#    6201     return self[name]
# -> 6202 return object.__getattribute__(self, name)
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
vdate = print(int_enel['DataInicioInterrupcao'].dtype)
vdate
# Out:
# object

# %%
 diti = int_enel['DataInicioInterrupcao'] = pd.to_datetime(int_enel['DataInicioInterrupcao'], errors='coerce')
diti
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_3832\1285484453.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   diti = int_enel['DataInicioInterrupcao'] = pd.to_datetime(int_enel['DataInicioInterrupcao'], errors='coerce')
# 0      2017-11-29
# 1      2017-11-29
# 2      2017-11-29
# 3      2017-11-29
# 4      2017-11-30
#           ...
# 4995   2017-12-11
# 4996   2017-12-11
# 4997   2017-12-11
# 4998   2017-12-11
# 4999          NaT
# Name: DataInicioInterrupcao, Length: 5000, dtype: datetime64[ns]

# %%
int_enel['DataInicioInterrupcao'] = pd.to_datetime(int_enel['DataInicioInterrupcao'])
'''
ssssssssss

'''''''''
# Out:
# '\nssssssssss\n\n'

# %%
int_enel['DataInicioInterrupcao'] = pd.to_datetime(int_enel['DataInicioInterrupcao'])

# %%
resultado = int_enel.groupby('HoraInicioInterrupcao')['VlrIndiceEnviado'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 resultado = int_enel.groupby('HoraInicioInterrupcao')['VlrIndiceEnviado'].mean()
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
#    8874     keys=by,
#    8875     axis=axis,
#    8876     level=level,
#    8877     as_index=as_index,
#    8878     sort=sort,
#    8879     group_keys=group_keys,
#    8880     observed=observed,
#    8881     dropna=dropna,
#    8882 )
#
# ...

# %%
dat = int_enel['DataInicioInterrupcao'] = pd.to_datetime(int_enel['DataInicioInterrupcao'], errors='coerce')
dat
# Out:
# 0      2017-11-29
# 1      2017-11-29
# 2      2017-11-29
# 3      2017-11-29
# 4      2017-11-30
#           ...
# 4995   2017-12-11
# 4996   2017-12-11
# 4997   2017-12-11
# 4998   2017-12-11
# 4999          NaT
# Name: DataInicioInterrupcao, Length: 5000, dtype: datetime64[ns]

# %%
print(int_enel['DataInicioInterrupcao'].head())
# Out:
# 0   2017-11-29
# 1   2017-11-29
# 2   2017-11-29
# 3   2017-11-29
# 4   2017-11-30
# Name: DataInicioInterrupcao, dtype: datetime64[ns]

# %%
date = int_enel = int_enel[int_enel['DataInicioInterrupcao'].notna()]
date
# Out:
#      DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 0                 26/05/2023                      TRINDADE
# 1                 26/05/2023                      BOM NOME
# 2                 26/05/2023                     ARARIPINA
# 3                 26/05/2023                   PAU AMARELO
# 4                 26/05/2023                     ARARIPINA
# ...                      ...                           ...
# 4994              26/05/2023                        VARZEA
# 4995              26/05/2023                      PRAZERES
# 4996              26/05/2023                     MACAXEIRA
# 4997              26/05/2023                      TIMBAUBA
# 4998              26/05/2023                    PONTEZINHA
#
#      DscAlimentadorSubestacao DscSubestacaoDistribuicao NumOrdemInterrupcao  \
# 0                    TDD-01C5                  TRINDADE   15326228_14086699
# 1                    SJB-01J3      SAO JOSE DO BELMONTE   15326358_14086719
# ...

# %%
d = int_enel['HoraInicioInterrupcao'] = int_enel['DataInicioInterrupcao'].dt.hour.astype(np.int64)
d
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_3832\12090601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d = int_enel['HoraInicioInterrupcao'] = int_enel['DataInicioInterrupcao'].dt.hour.astype(np.int64)
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4994    0
# 4995    0
# 4996    0
# 4997    0
# 4998    0
# Name: DataInicioInterrupcao, Length: 4999, dtype: int64

# %%
int_enel = int_enel[pd.to_numeric(int_enel['VlrIndiceEnviado'], errors='coerce').notna()]
int_enel
# Out:
#      DatGeracaoConjuntoDados DscConjuntoUnidadeConsumidora  \
# 0                 26/05/2023                      TRINDADE
# 1                 26/05/2023                      BOM NOME
# 2                 26/05/2023                     ARARIPINA
# 3                 26/05/2023                   PAU AMARELO
# 4                 26/05/2023                     ARARIPINA
# ...                      ...                           ...
# 4994              26/05/2023                        VARZEA
# 4995              26/05/2023                      PRAZERES
# 4996              26/05/2023                     MACAXEIRA
# 4997              26/05/2023                      TIMBAUBA
# 4998              26/05/2023                    PONTEZINHA
#
#      DscAlimentadorSubestacao DscSubestacaoDistribuicao NumOrdemInterrupcao  \
# 0                    TDD-01C5                  TRINDADE   15326228_14086699
# 1                    SJB-01J3      SAO JOSE DO BELMONTE   15326358_14086719
# ...

# %%
resultado = int_enel.groupby('HoraInicioInterrupcao')['VlrIndiceEnviado'].reset_index()
resultado
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 resultado = int_enel.groupby('HoraInicioInterrupcao')['VlrIndiceEnviado'].reset_index()
#       2 resultado
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\groupby\groupby.py:1307, in GroupBy.__getattr__(self, attr)
#    1304 if attr in self.obj:
#    1305     return self[attr]
# -> 1307 raise AttributeError(
#    1308     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1309 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'reset_index'

# %%
resultado2 = int_enel.groupby('HoraInicioInterrupcao')['VlrIndiceEnviado'].mean()
resultado2
# Out:
# HoraInicioInterrupcao
# 0    1046.985997
# Name: VlrIndiceEnviado, dtype: float64

# %%
resultado3 = resultado.to_frame(name='VlrIndiceEnviado').reset_index()
resultado3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 resultado3 = resultado.to_frame(name='VlrIndiceEnviado').reset_index()
#       2 resultado3
#
# NameError: name 'resultado' is not defined

# %%
resultado = int_enel.groupby(int_enel['DataInicioInterrupcao'].dt.date)['VlrIndiceEnviado'].mean().reset_index()
resultado
# Out:
#    DataInicioInterrupcao  VlrIndiceEnviado
# 0             2017-11-29       1044.000000
# 1             2017-11-30       1273.492537
# 2             2017-12-01        689.069820
# 3             2017-12-02       1121.095890
# 4             2017-12-03        464.453237
# 5             2017-12-04        531.621622
# 6             2017-12-05       1113.188571
# 7             2017-12-06       1371.125000
# 8             2017-12-07       2054.393868
# 9             2017-12-08        734.395876
# 10            2017-12-09        988.716639
# 11            2017-12-10        980.432990
# 12            2017-12-11       1272.418699

# %%
x = resultado.loc[:,['DataInicioInterrupcao']].index
y = resultado.loc[:,['NumNivelTensao']].values
plt.scatter(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 2
#       1 x = resultado.loc[:,['DataInicioInterrupcao']].index
# ----> 2 y = resultado.loc[:,['NumNivelTensao']].values
#       3 plt.scatter(x,y)
#       4 plt.show()
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File C:\analise\ambiente\Lib\site-packages\pandas\core\indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# ...
